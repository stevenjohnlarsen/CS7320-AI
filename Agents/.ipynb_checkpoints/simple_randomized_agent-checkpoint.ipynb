# %% [markdown]
# # Intelligent Agents: Vacuum-cleaner World
#
#
# ## Instructions
#
# Total Points: undergrad 10, graduate students 11
#
# Complete this notebook and submit it. The notebook needs to be a complete project report with
#
# * your implementation,
# * documentation including a short discussion of how your implementation works and your design choices, and
# * experimental results (e.g., tables and charts with simulation results) with a short discussion of what they mean.
#
# Use the provided notebook cells and insert additional code and markdown cells as needed.
#
# ## Introduction
#
# In this assignment you will implement a simulator environment for an automatic vacuum cleaner robot, a set of different agent programs, and perform a comparison study for cleaning a single room. Focus on the __cleaning phase__ which starts when the robot is activated and ends when the last dirty square is cleaned. Someone else will take care of the agent program needed to navigate back to the charging station after the room is clean.
#
# ## PEAS description of the cleaning phase
#
# __Performance Measure:__ Each action costs 1 energy unit. The performance is measured as the sum of the energy units used to clean the whole room.
#
# __Environment:__ A room with $n \times n$ squares where $n = 5$. Dirt is randomly placed on each square with probability $p = 0.2$. For simplicity, you can assume that the agent knows the size and the layout of the room (i.e., it knows $n$). To starte, the agent is placed on a random square.
#
# __Actuators:__ The agent can `clean` the current square or move to an adjacent square by going `north`, `east`, `south`, or `west`.
#
# __Sensors:__ Four bumper sensors, one for north, east, south, and west; a dirt sensor reporting dirt in the current square.
#
#
# ## The agent program for a simple randomized agent
#
# The agent program is a function that gets sensor information (the current percepts) as the arguments. The arguments are:
#
# * A dictionary with boolean entries for the for bumper sensors `north`, `east`, `west`, `south`. E.g., if the agent is on the north-west corner, `bumpers` will be `{"north" : True, "east" : False, "south" : False, "west" : True}`.
# * The dirt sensor produces a boolean.
#
# The agent returns the chosen action as a string.
#
# Here is an example implementation for the agent program of a simple randomized agent:

# %%
from numpy import random
import numpy as np
from copy import copy, deepcopy

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import time
actions = ["north", "east", "west", "south", "suck"]


def simple_randomized_agent(bumpers, dirty):
    return random.choice(actions)

# %%
simple_randomized_agent({"north" : True, "east" : False, "south" : False, "west" : True}, True)
# Out:
# 'suck'

# %% [markdown]
# __Note:__ This is not a rational intelligent agent. It ignores its sensors and may bump into a wall or not clean a dirty square. You will be asked to implement rational agents below.

# %% [markdown]
# ## Simple environment example
#
# This simple environment is infinite in size (bumpers are always `False`) and every square is always dirty, even if the agent cleans it. The environment function returns the performance measure which is here the number of cleaned squares (since all squares are constantly dirty, it is the number of `suck` actions by the agent).

# %%
from numpy import random
from pprint import pprint
def simple_environment(agent, max_steps, verbose = True):
    num_cleaned = 0
    
    for i in range(max_steps):
        dirty = True
        bumpers = {"north" : False, "south" : False, "west" : False, "east" : False}

        action = agent(bumpers, dirty)
        if (verbose): print("step", i , "- action:", action) 
        
        if (action == "suck"): 
            num_cleaned = num_cleaned + 1
        
    return num_cleaned

#simple_environment(simple_randomized_agent, max_steps = 10000,  verbose = False)

# %% [markdown]
# Do one simulation run with 20 steps.

# %%
simple_environment(simple_randomized_agent, max_steps = 20)
# Out:
# step 0 - action: south
# step 1 - action: west
# step 2 - action: north
# step 3 - action: suck
# step 4 - action: south
# step 5 - action: east
# step 6 - action: west
# step 7 - action: west
# step 8 - action: north
# step 9 - action: north
# step 10 - action: suck
# step 11 - action: west
# step 12 - action: south
# step 13 - action: suck
# step 14 - action: east
# step 15 - action: west
# step 16 - action: suck
# step 17 - action: north
# step 18 - action: east
# step 19 - action: suck
# 5

# %% [markdown]
# # Tasks
#
# _Submission Instructions:_ Use this notebook to prepare your submission. Complete this section with your code and results. You can add additional Markdown blocks for your description, comments in the code and use mathplotlib to produce charts.
#
# _Note:_ Try to keep the code simple! In this course, we want to learn about the algorithms and we often do not need to use object-oriented design.
#
#
# ## Task 1: Implement a simulation environment [2 Points]
#
# The simple environment above is not very realistic. Your environment simulator needs to follow the PEAS description from above. It needs to:
#
# * Initialize the environment by storing the state of each square (clean/dirty) and making some dirty.
# * Keep track of the agent's position.
# * Call the agent function repeatedly and provide the agent function with the sensor inputs.
# * React to the agent's actions. E.g, by removing dirt from a square or moving the agent around unless there is a wall in the way.
# * Keep track of the performance measure. That is, track the agent's actions until all dirty squares are clean and count the number of actions it takes the agent to complete the task.
#
# The easiest implementation for the environment is to hold an 2-dimensional array to represent if squares are clean or dirty and to call the agent function in a loop until all squares are clean or a predefined number of steps have been reached (i.e., the robot runs out of energy).
#
# The simulation environment needs to work with the simple randomized agent program from above and then it can be used for your agent implementation in the tasks below.

# %%
def environment(agent, max_steps, verbose = True, length = 5, width = 5, room = '', dirty_count = 0):
    #local variables used to keep track of the room and the agent
    num_cleaned = 0
    possiblyDirty = [False, False, False, False, True]
    
    #establish the room    
    x_location = random.randint(length)
    y_location = random.randint(width)
    if room == '':
        room = [[]] * 5
        for x in range(length):
            room[x] = [False] * width
            for y in range(width):
                room[x][y] = random.choice(possiblyDirty)
                if(room[x][y]):
                    dirty_count = dirty_count + 1

        
            
    if (verbose):
        print('The room is set up')
        print(f"There is {dirty_count} dirty sqaures")
        print(f"The room size is {length}X{width}")
        print(f"The robot is {x_location},{y_location}")
        print(f"Starting actions")
        print(f"_______________________________________")
        
    #start making actions
    for i in range(max_steps):
        #set up the agents percepts
        dirty = room[x_location][y_location]
        bumpers = {"north" : y_location == 0, 
                   "south" : y_location == length - 1, 
                   "west" : x_location == 0, 
                   "east" : x_location == width - 1}
        if(verbose):
            print(f"the agent percives {dirty}, with bumpers: {bumpers}")
            print(f"\t and is in {x_location},{y_location}")
        action = agent(bumpers, dirty)
        if (verbose): print("step", i , "- action:", action) 
        
        if (action == "suck" and dirty): 
            num_cleaned = num_cleaned + 1
            dirty_count = dirty_count - 1
            room[x_location][y_location] = False
        elif (action == "east"):
            x_location  = min(width - 1, x_location + 1)
        elif (action == "west"):
            x_location  = max(0, x_location - 1)
        elif (action == "south"):
            y_location  = min(length -1, y_location + 1)
        elif (action == "north"):
            y_location  = max(0, y_location - 1)
        if(verbose):
            print(f"{x_location},{y_location},{dirty}")
            print(f"*****")
            print(f"Step {i} dirty tiles {dirty_count}")
        #check if the room is clean 
        if(dirty_count == 0):
            return i
    return max_steps + 1

# %% [markdown]
# # Test the Random Agent on this envirnment

# %%
environment(simple_randomized_agent, 1000, verbose = True, length = 5, width = 5, room = '', dirty_count = 0)
# Out:
# The room is set up
# There is 5 dirty sqaures
# The room size is 5X5
# The robot is 2,1
# Starting actions
# _______________________________________
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,1
# step 0 - action: south
# 2,2,False
# *****
# Step 0 dirty tiles 5
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,2
# step 1 - action: south
# 2,3,False
# *****
# Step 1 dirty tiles 5
# the agent percives True, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,3
# step 2 - action: north
# 2,2,True
# *****
# Step 2 dirty tiles 5
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,2
# step 3 - action: east
# 3,2,False
# *****
# Step 3 dirty tiles 5
# the agent percives True, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 3,2
# step 4 - action: south
# 3,3,True
# *****
# Step 4 dirty tiles 5
# the agent percives True, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 3,3
# step 5 - action: north
# 3,2,True
# *****
# Step 5 dirty tiles 5
# the agent percives True, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 3,2
# step 6 - action: north
# 3,1,True
# *****
# Step 6 dirty tiles 5
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 3,1
# step 7 - action: west
# 2,1,False
# *****
# Step 7 dirty tiles 5
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,1
# step 8 - action: south
# 2,2,False
# *****
# Step 8 dirty tiles 5
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,2
# step 9 - action: west
# 1,2,False
# *****
# Step 9 dirty tiles 5
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,2
# step 10 - action: north
# 1,1,False
# *****
# Step 10 dirty tiles 5
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,1
# step 11 - action: west
# 0,1,False
# *****
# Step 11 dirty tiles 5
# the agent percives True, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,1
# step 12 - action: east
# 1,1,True
# *****
# Step 12 dirty tiles 5
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,1
# step 13 - action: north
# 1,0,False
# *****
# Step 13 dirty tiles 5
# the agent percives False, with bumpers: {'north': True, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,0
# step 14 - action: south
# 1,1,False
# *****
# Step 14 dirty tiles 5
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,1
# step 15 - action: south
# 1,2,False
# *****
# Step 15 dirty tiles 5
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,2
# step 16 - action: south
# 1,3,False
# *****
# Step 16 dirty tiles 5
# the agent percives True, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,3
# step 17 - action: west
# 0,3,True
# *****
# Step 17 dirty tiles 5
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,3
# step 18 - action: north
# 0,2,False
# *****
# Step 18 dirty tiles 5
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,2
# step 19 - action: north
# 0,1,False
# *****
# Step 19 dirty tiles 5
# the agent percives True, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,1
# step 20 - action: suck
# 0,1,True
# *****
# Step 20 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,1
# step 21 - action: west
# 0,1,False
# *****
# Step 21 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,1
# step 22 - action: north
# 0,0,False
# *****
# Step 22 dirty tiles 4
# the agent percives False, with bumpers: {'north': True, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,0
# step 23 - action: south
# 0,1,False
# *****
# Step 23 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,1
# step 24 - action: south
# 0,2,False
# *****
# Step 24 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,2
# step 25 - action: east
# 1,2,False
# *****
# Step 25 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,2
# step 26 - action: west
# 0,2,False
# *****
# Step 26 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,2
# step 27 - action: suck
# 0,2,False
# *****
# Step 27 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,2
# step 28 - action: west
# 0,2,False
# *****
# Step 28 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,2
# step 29 - action: north
# 0,1,False
# *****
# Step 29 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,1
# step 30 - action: suck
# 0,1,False
# *****
# Step 30 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,1
# step 31 - action: west
# 0,1,False
# *****
# Step 31 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,1
# step 32 - action: east
# 1,1,False
# *****
# Step 32 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,1
# step 33 - action: suck
# 1,1,False
# *****
# Step 33 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,1
# step 34 - action: suck
# 1,1,False
# *****
# Step 34 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,1
# step 35 - action: north
# 1,0,False
# *****
# Step 35 dirty tiles 4
# the agent percives False, with bumpers: {'north': True, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,0
# step 36 - action: south
# 1,1,False
# *****
# Step 36 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,1
# step 37 - action: suck
# 1,1,False
# *****
# Step 37 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,1
# step 38 - action: west
# 0,1,False
# *****
# Step 38 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,1
# step 39 - action: east
# 1,1,False
# *****
# Step 39 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,1
# step 40 - action: suck
# 1,1,False
# *****
# Step 40 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,1
# step 41 - action: east
# 2,1,False
# *****
# Step 41 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,1
# step 42 - action: suck
# 2,1,False
# *****
# Step 42 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,1
# step 43 - action: suck
# 2,1,False
# *****
# Step 43 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,1
# step 44 - action: north
# 2,0,False
# *****
# Step 44 dirty tiles 4
# the agent percives False, with bumpers: {'north': True, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,0
# step 45 - action: west
# 1,0,False
# *****
# Step 45 dirty tiles 4
# the agent percives False, with bumpers: {'north': True, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,0
# step 46 - action: north
# 1,0,False
# *****
# Step 46 dirty tiles 4
# the agent percives False, with bumpers: {'north': True, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,0
# step 47 - action: west
# 0,0,False
# *****
# Step 47 dirty tiles 4
# the agent percives False, with bumpers: {'north': True, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,0
# step 48 - action: south
# 0,1,False
# *****
# Step 48 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,1
# step 49 - action: suck
# 0,1,False
# *****
# Step 49 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,1
# step 50 - action: south
# 0,2,False
# *****
# Step 50 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,2
# step 51 - action: east
# 1,2,False
# *****
# Step 51 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,2
# step 52 - action: west
# 0,2,False
# *****
# Step 52 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,2
# step 53 - action: suck
# 0,2,False
# *****
# Step 53 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,2
# step 54 - action: west
# 0,2,False
# *****
# Step 54 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,2
# step 55 - action: west
# 0,2,False
# *****
# Step 55 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,2
# step 56 - action: suck
# 0,2,False
# *****
# Step 56 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,2
# step 57 - action: suck
# 0,2,False
# *****
# Step 57 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,2
# step 58 - action: west
# 0,2,False
# *****
# Step 58 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,2
# step 59 - action: south
# 0,3,False
# *****
# Step 59 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,3
# step 60 - action: west
# 0,3,False
# *****
# Step 60 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,3
# step 61 - action: north
# 0,2,False
# *****
# Step 61 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,2
# step 62 - action: east
# 1,2,False
# *****
# Step 62 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,2
# step 63 - action: south
# 1,3,False
# *****
# Step 63 dirty tiles 4
# the agent percives True, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,3
# step 64 - action: east
# 2,3,True
# *****
# Step 64 dirty tiles 4
# the agent percives True, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,3
# step 65 - action: west
# 1,3,True
# *****
# Step 65 dirty tiles 4
# the agent percives True, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,3
# step 66 - action: west
# 0,3,True
# *****
# Step 66 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,3
# step 67 - action: east
# 1,3,False
# *****
# Step 67 dirty tiles 4
# the agent percives True, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,3
# step 68 - action: east
# 2,3,True
# *****
# Step 68 dirty tiles 4
# the agent percives True, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,3
# step 69 - action: suck
# 2,3,True
# *****
# Step 69 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,3
# step 70 - action: south
# 2,4,False
# *****
# Step 70 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 2,4
# step 71 - action: east
# 3,4,False
# *****
# Step 71 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 3,4
# step 72 - action: east
# 4,4,False
# *****
# Step 72 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': True}
# 	 and is in 4,4
# step 73 - action: suck
# 4,4,False
# *****
# Step 73 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': True}
# 	 and is in 4,4
# step 74 - action: south
# 4,4,False
# *****
# Step 74 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': True}
# 	 and is in 4,4
# step 75 - action: suck
# 4,4,False
# *****
# Step 75 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': True}
# 	 and is in 4,4
# step 76 - action: south
# 4,4,False
# *****
# Step 76 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': True}
# 	 and is in 4,4
# step 77 - action: east
# 4,4,False
# *****
# Step 77 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': True}
# 	 and is in 4,4
# step 78 - action: east
# 4,4,False
# *****
# Step 78 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': True}
# 	 and is in 4,4
# step 79 - action: north
# 4,3,False
# *****
# Step 79 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': True}
# 	 and is in 4,3
# step 80 - action: east
# 4,3,False
# *****
# Step 80 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': True}
# 	 and is in 4,3
# step 81 - action: south
# 4,4,False
# *****
# Step 81 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': True}
# 	 and is in 4,4
# step 82 - action: north
# 4,3,False
# *****
# Step 82 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': True}
# 	 and is in 4,3
# step 83 - action: east
# 4,3,False
# *****
# Step 83 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': True}
# 	 and is in 4,3
# step 84 - action: east
# 4,3,False
# *****
# Step 84 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': True}
# 	 and is in 4,3
# step 85 - action: suck
# 4,3,False
# *****
# Step 85 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': True}
# 	 and is in 4,3
# step 86 - action: south
# 4,4,False
# *****
# Step 86 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': True}
# 	 and is in 4,4
# step 87 - action: west
# 3,4,False
# *****
# Step 87 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 3,4
# step 88 - action: south
# 3,4,False
# *****
# Step 88 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 3,4
# step 89 - action: south
# 3,4,False
# *****
# Step 89 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 3,4
# step 90 - action: suck
# 3,4,False
# *****
# Step 90 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 3,4
# step 91 - action: west
# 2,4,False
# *****
# Step 91 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 2,4
# step 92 - action: suck
# 2,4,False
# *****
# Step 92 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 2,4
# step 93 - action: west
# 1,4,False
# *****
# Step 93 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 1,4
# step 94 - action: east
# 2,4,False
# *****
# Step 94 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 2,4
# step 95 - action: west
# 1,4,False
# *****
# Step 95 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 1,4
# step 96 - action: south
# 1,4,False
# *****
# Step 96 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 1,4
# step 97 - action: suck
# 1,4,False
# *****
# Step 97 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 1,4
# step 98 - action: south
# 1,4,False
# *****
# Step 98 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 1,4
# step 99 - action: south
# 1,4,False
# *****
# Step 99 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 1,4
# step 100 - action: east
# 2,4,False
# *****
# Step 100 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 2,4
# step 101 - action: suck
# 2,4,False
# *****
# Step 101 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 2,4
# step 102 - action: suck
# 2,4,False
# *****
# Step 102 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 2,4
# step 103 - action: west
# 1,4,False
# *****
# Step 103 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 1,4
# step 104 - action: south
# 1,4,False
# *****
# Step 104 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 1,4
# step 105 - action: suck
# 1,4,False
# *****
# Step 105 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 1,4
# step 106 - action: south
# 1,4,False
# *****
# Step 106 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 1,4
# step 107 - action: suck
# 1,4,False
# *****
# Step 107 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 1,4
# step 108 - action: north
# 1,3,False
# *****
# Step 108 dirty tiles 3
# the agent percives True, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,3
# step 109 - action: suck
# 1,3,True
# *****
# Step 109 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,3
# step 110 - action: south
# 1,4,False
# *****
# Step 110 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 1,4
# step 111 - action: south
# 1,4,False
# *****
# Step 111 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 1,4
# step 112 - action: south
# 1,4,False
# *****
# Step 112 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 1,4
# step 113 - action: suck
# 1,4,False
# *****
# Step 113 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 1,4
# step 114 - action: east
# 2,4,False
# *****
# Step 114 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 2,4
# step 115 - action: east
# 3,4,False
# *****
# Step 115 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 3,4
# step 116 - action: east
# 4,4,False
# *****
# Step 116 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': True}
# 	 and is in 4,4
# step 117 - action: suck
# 4,4,False
# *****
# Step 117 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': True}
# 	 and is in 4,4
# step 118 - action: west
# 3,4,False
# *****
# Step 118 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 3,4
# step 119 - action: suck
# 3,4,False
# *****
# Step 119 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 3,4
# step 120 - action: suck
# 3,4,False
# *****
# Step 120 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 3,4
# step 121 - action: west
# 2,4,False
# *****
# Step 121 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 2,4
# step 122 - action: west
# 1,4,False
# *****
# Step 122 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 1,4
# step 123 - action: north
# 1,3,False
# *****
# Step 123 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,3
# step 124 - action: east
# 2,3,False
# *****
# Step 124 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,3
# step 125 - action: south
# 2,4,False
# *****
# Step 125 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 2,4
# step 126 - action: north
# 2,3,False
# *****
# Step 126 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,3
# step 127 - action: north
# 2,2,False
# *****
# Step 127 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,2
# step 128 - action: east
# 3,2,False
# *****
# Step 128 dirty tiles 2
# the agent percives True, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 3,2
# step 129 - action: east
# 4,2,True
# *****
# Step 129 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': True}
# 	 and is in 4,2
# step 130 - action: east
# 4,2,False
# *****
# Step 130 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': True}
# 	 and is in 4,2
# step 131 - action: east
# 4,2,False
# *****
# Step 131 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': True}
# 	 and is in 4,2
# step 132 - action: suck
# 4,2,False
# *****
# Step 132 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': True}
# 	 and is in 4,2
# step 133 - action: north
# 4,1,False
# *****
# Step 133 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': True}
# 	 and is in 4,1
# step 134 - action: suck
# 4,1,False
# *****
# Step 134 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': True}
# 	 and is in 4,1
# step 135 - action: west
# 3,1,False
# *****
# Step 135 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 3,1
# step 136 - action: south
# 3,2,False
# *****
# Step 136 dirty tiles 2
# the agent percives True, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 3,2
# step 137 - action: north
# 3,1,True
# *****
# Step 137 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 3,1
# step 138 - action: suck
# 3,1,False
# *****
# Step 138 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 3,1
# step 139 - action: west
# 2,1,False
# *****
# Step 139 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,1
# step 140 - action: south
# 2,2,False
# *****
# Step 140 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,2
# step 141 - action: east
# 3,2,False
# *****
# Step 141 dirty tiles 2
# the agent percives True, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 3,2
# step 142 - action: west
# 2,2,True
# *****
# Step 142 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,2
# step 143 - action: south
# 2,3,False
# *****
# Step 143 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,3
# step 144 - action: east
# 3,3,False
# *****
# Step 144 dirty tiles 2
# the agent percives True, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 3,3
# step 145 - action: south
# 3,4,True
# *****
# Step 145 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 3,4
# step 146 - action: east
# 4,4,False
# *****
# Step 146 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': True}
# 	 and is in 4,4
# step 147 - action: north
# 4,3,False
# *****
# Step 147 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': True}
# 	 and is in 4,3
# step 148 - action: south
# 4,4,False
# *****
# Step 148 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': True}
# 	 and is in 4,4
# step 149 - action: north
# 4,3,False
# *****
# Step 149 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': True}
# 	 and is in 4,3
# step 150 - action: south
# 4,4,False
# *****
# Step 150 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': True}
# 	 and is in 4,4
# step 151 - action: suck
# 4,4,False
# *****
# Step 151 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': True}
# 	 and is in 4,4
# step 152 - action: south
# 4,4,False
# *****
# Step 152 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': True}
# 	 and is in 4,4
# step 153 - action: suck
# 4,4,False
# *****
# Step 153 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': True}
# 	 and is in 4,4
# step 154 - action: west
# 3,4,False
# *****
# Step 154 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 3,4
# step 155 - action: west
# 2,4,False
# *****
# Step 155 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 2,4
# step 156 - action: north
# 2,3,False
# *****
# Step 156 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,3
# step 157 - action: suck
# 2,3,False
# *****
# Step 157 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,3
# step 158 - action: north
# 2,2,False
# *****
# Step 158 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,2
# step 159 - action: east
# 3,2,False
# *****
# Step 159 dirty tiles 2
# the agent percives True, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 3,2
# step 160 - action: east
# 4,2,True
# *****
# Step 160 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': True}
# 	 and is in 4,2
# step 161 - action: south
# 4,3,False
# *****
# Step 161 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': True}
# 	 and is in 4,3
# step 162 - action: east
# 4,3,False
# *****
# Step 162 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': True}
# 	 and is in 4,3
# step 163 - action: suck
# 4,3,False
# *****
# Step 163 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': True}
# 	 and is in 4,3
# step 164 - action: east
# 4,3,False
# *****
# Step 164 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': True}
# 	 and is in 4,3
# step 165 - action: south
# 4,4,False
# *****
# Step 165 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': True}
# 	 and is in 4,4
# step 166 - action: west
# 3,4,False
# *****
# Step 166 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 3,4
# step 167 - action: north
# 3,3,False
# *****
# Step 167 dirty tiles 2
# the agent percives True, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 3,3
# step 168 - action: north
# 3,2,True
# *****
# Step 168 dirty tiles 2
# the agent percives True, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 3,2
# step 169 - action: north
# 3,1,True
# *****
# Step 169 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 3,1
# step 170 - action: south
# 3,2,False
# *****
# Step 170 dirty tiles 2
# the agent percives True, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 3,2
# step 171 - action: south
# 3,3,True
# *****
# Step 171 dirty tiles 2
# the agent percives True, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 3,3
# step 172 - action: suck
# 3,3,True
# *****
# Step 172 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 3,3
# step 173 - action: suck
# 3,3,False
# *****
# Step 173 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 3,3
# step 174 - action: south
# 3,4,False
# *****
# Step 174 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 3,4
# step 175 - action: suck
# 3,4,False
# *****
# Step 175 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 3,4
# step 176 - action: west
# 2,4,False
# *****
# Step 176 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 2,4
# step 177 - action: south
# 2,4,False
# *****
# Step 177 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 2,4
# step 178 - action: north
# 2,3,False
# *****
# Step 178 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,3
# step 179 - action: suck
# 2,3,False
# *****
# Step 179 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,3
# step 180 - action: west
# 1,3,False
# *****
# Step 180 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,3
# step 181 - action: south
# 1,4,False
# *****
# Step 181 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 1,4
# step 182 - action: east
# 2,4,False
# *****
# Step 182 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 2,4
# step 183 - action: south
# 2,4,False
# *****
# Step 183 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 2,4
# step 184 - action: suck
# 2,4,False
# *****
# Step 184 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 2,4
# step 185 - action: north
# 2,3,False
# *****
# Step 185 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,3
# step 186 - action: east
# 3,3,False
# *****
# Step 186 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 3,3
# step 187 - action: suck
# 3,3,False
# *****
# Step 187 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 3,3
# step 188 - action: south
# 3,4,False
# *****
# Step 188 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 3,4
# step 189 - action: south
# 3,4,False
# *****
# Step 189 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 3,4
# step 190 - action: south
# 3,4,False
# *****
# Step 190 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 3,4
# step 191 - action: suck
# 3,4,False
# *****
# Step 191 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 3,4
# step 192 - action: south
# 3,4,False
# *****
# Step 192 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 3,4
# step 193 - action: south
# 3,4,False
# *****
# Step 193 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 3,4
# step 194 - action: north
# 3,3,False
# *****
# Step 194 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 3,3
# step 195 - action: east
# 4,3,False
# *****
# Step 195 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': True}
# 	 and is in 4,3
# step 196 - action: south
# 4,4,False
# *****
# Step 196 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': True}
# 	 and is in 4,4
# step 197 - action: north
# 4,3,False
# *****
# Step 197 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': True}
# 	 and is in 4,3
# step 198 - action: west
# 3,3,False
# *****
# Step 198 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 3,3
# step 199 - action: east
# 4,3,False
# *****
# Step 199 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': True}
# 	 and is in 4,3
# step 200 - action: east
# 4,3,False
# *****
# Step 200 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': True}
# 	 and is in 4,3
# step 201 - action: south
# 4,4,False
# *****
# Step 201 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': True}
# 	 and is in 4,4
# step 202 - action: south
# 4,4,False
# *****
# Step 202 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': True}
# 	 and is in 4,4
# step 203 - action: north
# 4,3,False
# *****
# Step 203 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': True}
# 	 and is in 4,3
# step 204 - action: west
# 3,3,False
# *****
# Step 204 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 3,3
# step 205 - action: south
# 3,4,False
# *****
# Step 205 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 3,4
# step 206 - action: west
# 2,4,False
# *****
# Step 206 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 2,4
# step 207 - action: west
# 1,4,False
# *****
# Step 207 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 1,4
# step 208 - action: west
# 0,4,False
# *****
# Step 208 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': True, 'east': False}
# 	 and is in 0,4
# step 209 - action: suck
# 0,4,False
# *****
# Step 209 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': True, 'east': False}
# 	 and is in 0,4
# step 210 - action: east
# 1,4,False
# *****
# Step 210 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 1,4
# step 211 - action: west
# 0,4,False
# *****
# Step 211 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': True, 'east': False}
# 	 and is in 0,4
# step 212 - action: west
# 0,4,False
# *****
# Step 212 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': True, 'east': False}
# 	 and is in 0,4
# step 213 - action: suck
# 0,4,False
# *****
# Step 213 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': True, 'east': False}
# 	 and is in 0,4
# step 214 - action: east
# 1,4,False
# *****
# Step 214 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 1,4
# step 215 - action: north
# 1,3,False
# *****
# Step 215 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,3
# step 216 - action: north
# 1,2,False
# *****
# Step 216 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,2
# step 217 - action: suck
# 1,2,False
# *****
# Step 217 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,2
# step 218 - action: suck
# 1,2,False
# *****
# Step 218 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,2
# step 219 - action: east
# 2,2,False
# *****
# Step 219 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,2
# step 220 - action: south
# 2,3,False
# *****
# Step 220 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,3
# step 221 - action: west
# 1,3,False
# *****
# Step 221 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,3
# step 222 - action: east
# 2,3,False
# *****
# Step 222 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,3
# step 223 - action: south
# 2,4,False
# *****
# Step 223 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 2,4
# step 224 - action: west
# 1,4,False
# *****
# Step 224 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 1,4
# step 225 - action: south
# 1,4,False
# *****
# Step 225 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 1,4
# step 226 - action: west
# 0,4,False
# *****
# Step 226 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': True, 'east': False}
# 	 and is in 0,4
# step 227 - action: west
# 0,4,False
# *****
# Step 227 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': True, 'east': False}
# 	 and is in 0,4
# step 228 - action: suck
# 0,4,False
# *****
# Step 228 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': True, 'east': False}
# 	 and is in 0,4
# step 229 - action: suck
# 0,4,False
# *****
# Step 229 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': True, 'east': False}
# 	 and is in 0,4
# step 230 - action: west
# 0,4,False
# *****
# Step 230 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': True, 'east': False}
# 	 and is in 0,4
# step 231 - action: west
# 0,4,False
# *****
# Step 231 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': True, 'east': False}
# 	 and is in 0,4
# step 232 - action: east
# 1,4,False
# *****
# Step 232 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 1,4
# step 233 - action: west
# 0,4,False
# *****
# Step 233 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': True, 'east': False}
# 	 and is in 0,4
# step 234 - action: north
# 0,3,False
# *****
# Step 234 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,3
# step 235 - action: north
# 0,2,False
# *****
# Step 235 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,2
# step 236 - action: west
# 0,2,False
# *****
# Step 236 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,2
# step 237 - action: north
# 0,1,False
# *****
# Step 237 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,1
# step 238 - action: west
# 0,1,False
# *****
# Step 238 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,1
# step 239 - action: suck
# 0,1,False
# *****
# Step 239 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,1
# step 240 - action: west
# 0,1,False
# *****
# Step 240 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,1
# step 241 - action: suck
# 0,1,False
# *****
# Step 241 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,1
# step 242 - action: north
# 0,0,False
# *****
# Step 242 dirty tiles 1
# the agent percives False, with bumpers: {'north': True, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,0
# step 243 - action: west
# 0,0,False
# *****
# Step 243 dirty tiles 1
# the agent percives False, with bumpers: {'north': True, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,0
# step 244 - action: north
# 0,0,False
# *****
# Step 244 dirty tiles 1
# the agent percives False, with bumpers: {'north': True, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,0
# step 245 - action: suck
# 0,0,False
# *****
# Step 245 dirty tiles 1
# the agent percives False, with bumpers: {'north': True, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,0
# step 246 - action: west
# 0,0,False
# *****
# Step 246 dirty tiles 1
# the agent percives False, with bumpers: {'north': True, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,0
# step 247 - action: suck
# 0,0,False
# *****
# Step 247 dirty tiles 1
# the agent percives False, with bumpers: {'north': True, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,0
# step 248 - action: north
# 0,0,False
# *****
# Step 248 dirty tiles 1
# the agent percives False, with bumpers: {'north': True, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,0
# step 249 - action: south
# 0,1,False
# *****
# Step 249 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,1
# step 250 - action: suck
# 0,1,False
# *****
# Step 250 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,1
# step 251 - action: east
# 1,1,False
# *****
# Step 251 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,1
# step 252 - action: west
# 0,1,False
# *****
# Step 252 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,1
# step 253 - action: east
# 1,1,False
# *****
# Step 253 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,1
# step 254 - action: north
# 1,0,False
# *****
# Step 254 dirty tiles 1
# the agent percives False, with bumpers: {'north': True, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,0
# step 255 - action: south
# 1,1,False
# *****
# Step 255 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,1
# step 256 - action: east
# 2,1,False
# *****
# Step 256 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,1
# step 257 - action: east
# 3,1,False
# *****
# Step 257 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 3,1
# step 258 - action: suck
# 3,1,False
# *****
# Step 258 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 3,1
# step 259 - action: west
# 2,1,False
# *****
# Step 259 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,1
# step 260 - action: east
# 3,1,False
# *****
# Step 260 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 3,1
# step 261 - action: west
# 2,1,False
# *****
# Step 261 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,1
# step 262 - action: east
# 3,1,False
# *****
# Step 262 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 3,1
# step 263 - action: south
# 3,2,False
# *****
# Step 263 dirty tiles 1
# the agent percives True, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 3,2
# step 264 - action: north
# 3,1,True
# *****
# Step 264 dirty tiles 1
# ...
# *****
# Step 431 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': True}
# 	 and is in 4,3
# step 432 - action: south
# 4,4,False
# *****
# Step 432 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': True}
# 	 and is in 4,4
# step 433 - action: south
# 4,4,False
# *****
# Step 433 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': True}
# 	 and is in 4,4
# step 434 - action: east
# 4,4,False
# *****
# Step 434 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': True}
# 	 and is in 4,4
# step 435 - action: east
# 4,4,False
# *****
# Step 435 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': True}
# 	 and is in 4,4
# step 436 - action: suck
# 4,4,False
# *****
# Step 436 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': True}
# 	 and is in 4,4
# step 437 - action: east
# 4,4,False
# *****
# Step 437 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': True}
# 	 and is in 4,4
# step 438 - action: east
# 4,4,False
# *****
# Step 438 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': True}
# 	 and is in 4,4
# step 439 - action: east
# 4,4,False
# *****
# Step 439 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': True}
# 	 and is in 4,4
# step 440 - action: west
# 3,4,False
# *****
# Step 440 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 3,4
# step 441 - action: west
# 2,4,False
# *****
# Step 441 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 2,4
# step 442 - action: east
# 3,4,False
# *****
# Step 442 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 3,4
# step 443 - action: north
# 3,3,False
# *****
# Step 443 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 3,3
# step 444 - action: west
# 2,3,False
# *****
# Step 444 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,3
# step 445 - action: south
# 2,4,False
# *****
# Step 445 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 2,4
# step 446 - action: suck
# 2,4,False
# *****
# Step 446 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 2,4
# step 447 - action: east
# 3,4,False
# *****
# Step 447 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 3,4
# step 448 - action: north
# 3,3,False
# *****
# Step 448 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 3,3
# step 449 - action: west
# 2,3,False
# *****
# Step 449 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,3
# step 450 - action: south
# 2,4,False
# *****
# Step 450 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 2,4
# step 451 - action: south
# 2,4,False
# *****
# Step 451 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 2,4
# step 452 - action: south
# 2,4,False
# *****
# Step 452 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 2,4
# step 453 - action: east
# 3,4,False
# *****
# Step 453 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 3,4
# step 454 - action: suck
# 3,4,False
# *****
# Step 454 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 3,4
# step 455 - action: south
# 3,4,False
# *****
# Step 455 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 3,4
# step 456 - action: east
# 4,4,False
# *****
# Step 456 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': True}
# 	 and is in 4,4
# step 457 - action: north
# 4,3,False
# *****
# Step 457 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': True}
# 	 and is in 4,3
# step 458 - action: north
# 4,2,False
# *****
# Step 458 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': True}
# 	 and is in 4,2
# step 459 - action: east
# 4,2,False
# *****
# Step 459 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': True}
# 	 and is in 4,2
# step 460 - action: south
# 4,3,False
# *****
# Step 460 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': True}
# 	 and is in 4,3
# step 461 - action: east
# 4,3,False
# *****
# Step 461 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': True}
# 	 and is in 4,3
# step 462 - action: west
# 3,3,False
# *****
# Step 462 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 3,3
# step 463 - action: west
# 2,3,False
# *****
# Step 463 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,3
# step 464 - action: west
# 1,3,False
# *****
# Step 464 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,3
# step 465 - action: suck
# 1,3,False
# *****
# Step 465 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,3
# step 466 - action: east
# 2,3,False
# *****
# Step 466 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,3
# step 467 - action: south
# 2,4,False
# *****
# Step 467 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': False, 'east': False}
# 	 and is in 2,4
# step 468 - action: north
# 2,3,False
# *****
# Step 468 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,3
# step 469 - action: west
# 1,3,False
# *****
# Step 469 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,3
# step 470 - action: west
# 0,3,False
# *****
# Step 470 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,3
# step 471 - action: north
# 0,2,False
# *****
# Step 471 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,2
# step 472 - action: north
# 0,1,False
# *****
# Step 472 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,1
# step 473 - action: east
# 1,1,False
# *****
# Step 473 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,1
# step 474 - action: suck
# 1,1,False
# *****
# Step 474 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,1
# step 475 - action: suck
# 1,1,False
# *****
# Step 475 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,1
# step 476 - action: suck
# 1,1,False
# *****
# Step 476 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,1
# step 477 - action: east
# 2,1,False
# *****
# Step 477 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,1
# step 478 - action: west
# 1,1,False
# *****
# Step 478 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,1
# step 479 - action: west
# 0,1,False
# *****
# Step 479 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,1
# step 480 - action: north
# 0,0,False
# *****
# Step 480 dirty tiles 1
# the agent percives False, with bumpers: {'north': True, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,0
# step 481 - action: suck
# 0,0,False
# *****
# Step 481 dirty tiles 1
# the agent percives False, with bumpers: {'north': True, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,0
# step 482 - action: north
# 0,0,False
# *****
# Step 482 dirty tiles 1
# the agent percives False, with bumpers: {'north': True, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,0
# step 483 - action: east
# 1,0,False
# *****
# Step 483 dirty tiles 1
# the agent percives False, with bumpers: {'north': True, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,0
# step 484 - action: east
# 2,0,False
# *****
# Step 484 dirty tiles 1
# the agent percives False, with bumpers: {'north': True, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,0
# step 485 - action: west
# 1,0,False
# *****
# Step 485 dirty tiles 1
# the agent percives False, with bumpers: {'north': True, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,0
# step 486 - action: suck
# 1,0,False
# *****
# Step 486 dirty tiles 1
# the agent percives False, with bumpers: {'north': True, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,0
# step 487 - action: south
# 1,1,False
# *****
# Step 487 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,1
# step 488 - action: west
# 0,1,False
# *****
# Step 488 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,1
# step 489 - action: suck
# 0,1,False
# *****
# Step 489 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,1
# step 490 - action: west
# 0,1,False
# *****
# Step 490 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,1
# step 491 - action: east
# 1,1,False
# *****
# Step 491 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,1
# step 492 - action: suck
# 1,1,False
# *****
# Step 492 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,1
# step 493 - action: north
# 1,0,False
# *****
# Step 493 dirty tiles 1
# the agent percives False, with bumpers: {'north': True, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,0
# step 494 - action: west
# 0,0,False
# *****
# Step 494 dirty tiles 1
# the agent percives False, with bumpers: {'north': True, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,0
# step 495 - action: suck
# 0,0,False
# *****
# Step 495 dirty tiles 1
# the agent percives False, with bumpers: {'north': True, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,0
# step 496 - action: north
# 0,0,False
# *****
# Step 496 dirty tiles 1
# the agent percives False, with bumpers: {'north': True, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,0
# step 497 - action: west
# 0,0,False
# *****
# Step 497 dirty tiles 1
# the agent percives False, with bumpers: {'north': True, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,0
# step 498 - action: suck
# 0,0,False
# *****
# Step 498 dirty tiles 1
# the agent percives False, with bumpers: {'north': True, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,0
# step 499 - action: suck
# 0,0,False
# *****
# Step 499 dirty tiles 1
# the agent percives False, with bumpers: {'north': True, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,0
# step 500 - action: north
# 0,0,False
# *****
# Step 500 dirty tiles 1
# the agent percives False, with bumpers: {'north': True, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,0
# step 501 - action: south
# 0,1,False
# *****
# Step 501 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,1
# step 502 - action: north
# 0,0,False
# *****
# Step 502 dirty tiles 1
# the agent percives False, with bumpers: {'north': True, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,0
# step 503 - action: north
# 0,0,False
# *****
# Step 503 dirty tiles 1
# the agent percives False, with bumpers: {'north': True, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,0
# step 504 - action: suck
# 0,0,False
# *****
# Step 504 dirty tiles 1
# the agent percives False, with bumpers: {'north': True, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,0
# step 505 - action: south
# 0,1,False
# *****
# Step 505 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,1
# step 506 - action: east
# 1,1,False
# *****
# Step 506 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,1
# step 507 - action: west
# 0,1,False
# *****
# Step 507 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,1
# step 508 - action: suck
# 0,1,False
# *****
# Step 508 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,1
# step 509 - action: south
# 0,2,False
# *****
# Step 509 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,2
# step 510 - action: suck
# 0,2,False
# *****
# Step 510 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,2
# step 511 - action: north
# 0,1,False
# *****
# Step 511 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,1
# step 512 - action: suck
# 0,1,False
# *****
# Step 512 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,1
# step 513 - action: north
# 0,0,False
# *****
# Step 513 dirty tiles 1
# the agent percives False, with bumpers: {'north': True, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,0
# step 514 - action: east
# 1,0,False
# *****
# Step 514 dirty tiles 1
# the agent percives False, with bumpers: {'north': True, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,0
# step 515 - action: east
# 2,0,False
# *****
# Step 515 dirty tiles 1
# the agent percives False, with bumpers: {'north': True, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,0
# step 516 - action: south
# 2,1,False
# *****
# Step 516 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,1
# step 517 - action: east
# 3,1,False
# *****
# Step 517 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 3,1
# step 518 - action: south
# 3,2,False
# *****
# Step 518 dirty tiles 1
# the agent percives True, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 3,2
# step 519 - action: suck
# 3,2,True
# *****
# Step 519 dirty tiles 0
# 519

# %% [markdown]
# ## Task 2:  Implement a simple reflex agent [1 Point]
#
# The simple reflex agent randomly walks around but reacts to the bumper sensor by not bumping into the wall and to dirt with sucking.

# %%
def simple_reflex_agent(bumpers, dirty):
    movements = []
    if dirty:
        return 'suck'
    if bumpers['north'] == False:
        movements.append('north')
    if bumpers['south'] == False:
        movements.append('south')
    if bumpers['east'] == False:
        movements.append('east')
    if bumpers['west'] == False:
        movements.append('west')
    return random.choice(movements)

#just some unit tests all should return true
print(simple_reflex_agent({'north': False, 'south': False, 'west': True, 'east': False}, True) == 'suck')
print(simple_reflex_agent({'north': False, 'south': True, 'west': True, 'east': True}, False) == 'north')
print(simple_reflex_agent({'north': True, 'south': False, 'west': True, 'east': True}, False) == 'south')
print(simple_reflex_agent({'north': True, 'south': True, 'west': True, 'east': False}, False) == 'east')
print(simple_reflex_agent({'north': True, 'south': True, 'west': False, 'east': True}, False) == 'west')
# Out:
# True
# True
# True
# True
# True

# %% [markdown]
# # Test this Agent on the Above Envirnment

# %%
environment(simple_reflex_agent, max_steps = 1000, verbose=True)
# Out:
# The room is set up
# There is 4 dirty sqaures
# The room size is 5X5
# The robot is 0,4
# Starting actions
# _______________________________________
# the agent percives False, with bumpers: {'north': False, 'south': True, 'west': True, 'east': False}
# 	 and is in 0,4
# step 0 - action: north
# 0,3,False
# *****
# Step 0 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,3
# step 1 - action: east
# 1,3,False
# *****
# Step 1 dirty tiles 4
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,3
# step 2 - action: north
# 1,2,False
# *****
# Step 2 dirty tiles 4
# the agent percives True, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,2
# step 3 - action: suck
# 1,2,True
# *****
# Step 3 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,2
# step 4 - action: west
# 0,2,False
# *****
# Step 4 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,2
# step 5 - action: east
# 1,2,False
# *****
# Step 5 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,2
# step 6 - action: north
# 1,1,False
# *****
# Step 6 dirty tiles 3
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,1
# step 7 - action: west
# 0,1,False
# *****
# Step 7 dirty tiles 3
# the agent percives True, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,1
# step 8 - action: suck
# 0,1,True
# *****
# Step 8 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,1
# step 9 - action: east
# 1,1,False
# *****
# Step 9 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,1
# step 10 - action: west
# 0,1,False
# *****
# Step 10 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,1
# step 11 - action: south
# 0,2,False
# *****
# Step 11 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': True, 'east': False}
# 	 and is in 0,2
# step 12 - action: east
# 1,2,False
# *****
# Step 12 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,2
# step 13 - action: south
# 1,3,False
# *****
# Step 13 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 1,3
# step 14 - action: east
# 2,3,False
# *****
# Step 14 dirty tiles 2
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 2,3
# step 15 - action: east
# 3,3,False
# *****
# Step 15 dirty tiles 2
# the agent percives True, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 3,3
# step 16 - action: suck
# 3,3,True
# *****
# Step 16 dirty tiles 1
# the agent percives False, with bumpers: {'north': False, 'south': False, 'west': False, 'east': False}
# 	 and is in 3,3
# step 17 - action: east
# 4,3,False
# *****
# Step 17 dirty tiles 1
# the agent percives True, with bumpers: {'north': False, 'south': False, 'west': False, 'east': True}
# 	 and is in 4,3
# step 18 - action: suck
# 4,3,True
# *****
# Step 18 dirty tiles 0
# 18

# %% [markdown]
# ## Task 3: Implement a model-based reflex agent [3 Point]
#
# This agent keeps track of the location and remembers where it has cleaned. Assume the agent knows how many squares the room has. It can move to a corner to determin its location and then is able to use more advanced navigation.
#
# _Note on implementing the state:_ You can use a global variable. In Python, you have to use the keyword `global` in your function for this to work (see: https://www.programiz.com/python-programming/global-keyword). Alternatively, you can define a class for your agent with a member variable for the state and a function for the agent program (see: https://www.w3schools.com/python/python_classes.asp).
#
# Describe how you define the __agent state__ and how your agent works before implementing it.

# %%
# Phases of the algorithm
# 1. Find a western wall, suck on the way and only move right. 
# 2. Find the Nothern corner suck on the way and only move up.
# 3. Move East till it hits a western wall
# 4. Move south 1
# 5. Move West till hits a wall
# 6. Move south 1 and move to pahse 3

# %%
class model_agent:
    def __init__(self):
        self.phase = 1
    def act(self, bumpers, dirt):
        if dirt:
            return 'suck'
        if self.phase == 1:
            return self.phase1(bumpers, dirt)
        elif self.phase == 2:
            return self.phase2(bumpers, dirt)
        elif self.phase == 3:
            return self.phase3(bumpers, dirt)
        elif self.phase == 4:
            return self.phase4(bumpers, dirt)
        elif self.phase == 5:
            return self.phase5(bumpers, dirt)
        elif self.phase == 6:
            return self.phase6(bumpers, dirt)
        return 'DONE'
    
    # in all the functions below it can be assumed the tile the vacuum is on is clean
    def phase1(self, bumpers, dirt):
        if bumpers['west'] == True:
            self.phase = self.phase + 1
            return self.act(bumpers, dirt)
        else:
            return 'west'
    def phase2(self, bumpers, dirt):
        if bumpers['north'] == True:
            self.phase = self.phase + 1
            return self.act(bumpers, dirt)
        else:
            return 'north'
    def phase3(self, bumpers, dirt):
        if bumpers['east'] == True:
            self.phase = self.phase + 1
            return self.act(bumpers, dirt)
        else:
            return 'east'
    def phase4(self, bumpers, dirt):
        self.phase = self.phase + 1
        return 'south'
    def phase5(self, bumpers, dirt):
        if bumpers['west'] == True:
            self.phase = self.phase + 1
            return self.act(bumpers, dirt)
        else:
            return 'west'
    def phase6(self, bumpers, dirt):
        self.phase = 3
        return 'south'

# %% [markdown]
# # Test the  Agent on the environment

# %%
agent = model_agent()
environment(agent.act, max_steps=50, verbose=False)
# Out:
# 33

# %% [markdown]
# ## Task 4: Simulation study [3 Points]
#
# Compare the performance of the agents using different size environments. E.g., $5 \times 5$, $10 \times 10$ and
# $100 \times 100$. Use at least 100 random runs for each. Present the results in a suitable format (tables, graphs) and discuss the differences.

# %% [markdown]
# # A Simulation function

# %%
def simulation(width, length, numberOfRuns, max_steps = 1000, verbose = False, inner_verbose = False):
    index = []
    simple_randomized_agent_array = []
    simple_reflex_agent_array = []
    model_agent_out_array = []
    num_dirty_array = []
    for i in range(numberOfRuns):
        ma = model_agent()
        dirty_count = 0
        possiblyDirty = [False, False, False, False, True]
        room = [[]] * length
        for x in range(length):
            room[x] = [False] * width
            for y in range(width):
                room[x][y] = random.choice(possiblyDirty)
                if(room[x][y]):
                    dirty_count = dirty_count + 1
        room2 = deepcopy(room)
        room3 = deepcopy(room)

        simple_randomized_agent_out = environment(simple_randomized_agent, 
                    max_steps = max_steps, verbose = inner_verbose, 
                    length = length, 
                    width = width, 
                    room = room,
                    dirty_count = dirty_count) 
        simple_reflex_agent_out = environment(simple_reflex_agent, 
                    max_steps = max_steps, verbose = inner_verbose, 
                    length = length, 
                    width = width, 
                    room = room2,
                    dirty_count = dirty_count) 
        model_agent_out = environment(ma.act, 
                    max_steps = max_steps, verbose = inner_verbose, 
                    length = length, 
                    width = width, 
                    room = room3,
                    dirty_count = dirty_count) 
        index.append(i)
        num_dirty_array.append(dirty_count)
        simple_randomized_agent_array.append(simple_randomized_agent_out)
        simple_reflex_agent_array.append(simple_reflex_agent_out)
        model_agent_out_array.append(model_agent_out)
        if(verbose):
            print(f"Random: {simple_randomized_agent_out} \t Reflex: {simple_reflex_agent_out} \t Model: {model_agent_out}")
    
    df = pd.DataFrame({'index':index,
                      'randomized_agent':simple_randomized_agent_array,
                      'reflex_agent':simple_reflex_agent_array,
                      'model_agent':model_agent_out_array,
                      'num_dirty': num_dirty_array})
    return df

# %% [markdown]
# # Test the simulation

# %%
df = simulation(5,5,5, max_steps= 1000000, verbose = False, inner_verbose = False)
print(df)
# Out:
#    index  randomized_agent  reflex_agent  model_agent_out  num_dirty
# 0      0               588            64               28          6
# 1      1               481            80               26          7
# 2      2               315           134               22          4
# 3      3               376           192               36          7
# 4      4               533            55               33          6

# %% [markdown]
# # Analyze the Simulation with Many Variables

# %%
#These are helper functions for us to use later
def plotDataFrameAll(df, title = ''):
    ax = df.plot(kind='scatter',
             y='randomized_agent',
             x='index',
             color='blue', 
             label='randomized_agent',
             alpha=0.3)
    df.plot(kind='scatter',
             y='reflex_agent',
             x='index',
             color='red',
             figsize=(20,5), ax = ax, 
             label='reflex_agent',
             alpha=0.3)
    df.plot(kind='scatter',
             y='model_agent',
             x='index',
             color='yellow',
             figsize=(20,5), ax = ax, 
             label='model_agent',
             alpha=0.3)
    ax.set_title(title)
    
def plotDataFrameRelfexModel(df, title = ''):
    ax = df.plot(kind='scatter',
             y='reflex_agent',
             x='index',
             color='red',
             figsize=(20,5), 
             label='reflex_agent',
             alpha=0.3)
    df.plot(kind='scatter',
             y='model_agent',
             x='index',
             color='yellow',
             figsize=(20,5), ax = ax, 
             label='model_agent',
             alpha=0.3)
    ax.set_title(title)

# %% [markdown]
# # Run 5 X 5 for More Cases

# %%
df = simulation(5,5,1000, max_steps= 1000000, verbose = False, inner_verbose = False)
plotDataFrame(df, '5X5')

# %% [markdown]
# Here we can see the clear advatange the model based agent gets.  The pure random anget really performs slowly. Below we will look at just the model vs reflex 5X5

# %%
plotDataFrameRelfexModel(df, '5X5')

# %% [raw]
# Above gives a zoomed in picture of this comparison.  We see the model agent outperforming the reflex agent more often that not.  As the grid expands we will continue to look at this relationship.  It will become less and less likely for the random reflex agent to beat the model based agent.

# %% [markdown]
# ## Task 5: Robustness of the agent implementations [1 Point]
#
# Describe how your agent implementations will perform
#
# * if it is put into a rectangular room with unknown size,
# * if the cleaning area can have an iregular shape (e.g., a hallway connecting two rooms), or
# * if the room contains obstacles (i.e., squares that it cannot pass through and trigger the bumper sensors).

# %%
# Answer goes here

# %% [markdown]
# ## Graduate student advanced task: Obstacles [1 Point]
#
# __Undergraduate students:__ This is a bonus task you can attempt if you like [+1 Bonus point].
#
# 1. Change your simulation environment tor run experiments for the following problem: Add random obstacle squares that also trigger the bumper sensor. The agent does not know where the obstacles are. Observe how this changes the performance of the three implementations.
#
# 2. Describe what would need to be done to perform better with obstacles. Add code if you can.

# %%
# Your code and discussion goes here

# %% [markdown]
# ## More advanced tasks to think about
#
# You can think about these:
#
# * __Unknown environment with obstacles:__ Implement an agent for an environment where the agent does not know how large the environment is (we assume it is rectangular), where it starts or where the obstacles are. An option would be to always move to the closest unchecked/uncleaned square.
#
# * __Utility-based agent:__ Change the environment, so each square has a fixed probability of getting dirty again. We assume the agent has learned this information over time. For the implementation, we give this information to the agent as a 2-dimensional array of probabilities  Cleaning one dirty square produces a utility of 1. Implement a utility-based agent that maximizes the expected utility over one full charge which lasts for 10000 time steps. This is very tricky!
